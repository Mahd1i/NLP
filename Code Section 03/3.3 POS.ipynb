# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp('''The son of a salesman who later operated an electrochemical factory, 
instein was born in the German Empire, but moved to Switzerland in 1895 and 
renounced his German citizenship in 1896. Specializing in physics and
mathematics, he received his academic teaching diploma from the Swiss 
Federal Polytechnic School (German: eidgenössische polytechnische Schule) 
in Zürich in 1900. The following year, he acquired Swiss citizenship, which
he kept for his entire life. After initially struggling to find work, from 
1902 to 1909 he was employed as a patent examiner at the Swiss Patent Office
in Bern.

''')


for token in doc1:
    print('Words is   : ' , token.text)
    print('POS is   : ' , token.pos ,'===',token.pos_  , '===', spacy.explain(token.pos_))
    print('Dep is   : ' , token.dep , '===',token.dep_, '===', spacy.explain(token.dep_))
    print('Tag is   : ' , token.tag , '===',token.tag_, '===', spacy.explain(token.tag_))
    print('-----------------------')
# Out:
# Words is   :  The
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  son
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  430 === nsubjpass === nominal subject (passive)
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  of
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  a
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  salesman
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  who
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  4808651922106831370 === WP === wh-pronoun, personal
# -----------------------
# Words is   :  later
# POS is   :  univ_pos_t.ADV === ADV === adverb
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  164681854541413346 === RB === adverb
# -----------------------
# Words is   :  operated
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  447 === relcl === relative clause modifier
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  an
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  electrochemical
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  factory
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  instein
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  was
# POS is   :  univ_pos_t.AUX === AUX === auxiliary
# Dep is   :  406 === auxpass === auxiliary (passive)
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  born
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  3822385049556375858 === VBN === verb, past participle
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  German
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Empire
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  but
# POS is   :  univ_pos_t.CCONJ === CCONJ === coordinating conjunction
# Dep is   :  407 === cc === coordinating conjunction
# Tag is   :  17571114184892886314 === CC === conjunction, coordinating
# -----------------------
# Words is   :  moved
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  410 === conj === conjunct
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  to
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Switzerland
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1895
# POS is   :  univ_pos_t.NUM === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  and
# POS is   :  univ_pos_t.CCONJ === CCONJ === coordinating conjunction
# Dep is   :  407 === cc === coordinating conjunction
# Tag is   :  17571114184892886314 === CC === conjunction, coordinating
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  renounced
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  410 === conj === conjunct
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  his
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  440 === poss === possession modifier
# Tag is   :  4062917326063685704 === PRP$ === pronoun, possessive
# -----------------------
# Words is   :  German
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  citizenship
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1896
# POS is   :  univ_pos_t.NUM === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  .
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  Specializing
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  399 === advcl === adverbial clause modifier
# Tag is   :  1534113631682161808 === VBG === verb, gerund or present participle
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  physics
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  and
# POS is   :  univ_pos_t.CCONJ === CCONJ === coordinating conjunction
# Dep is   :  407 === cc === coordinating conjunction
# Tag is   :  17571114184892886314 === CC === conjunction, coordinating
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  mathematics
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  410 === conj === conjunct
# Tag is   :  783433942507015291 === NNS === noun, plural
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  he
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  received
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  his
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  440 === poss === possession modifier
# Tag is   :  4062917326063685704 === PRP$ === pronoun, possessive
# -----------------------
# Words is   :  academic
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  teaching
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  diploma
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  from
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  Swiss
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  Federal
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Polytechnic
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  School
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  (
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  17111077179131903759 === -LRB- === left round bracket
# -----------------------
# Words is   :  German
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  :
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  11532473245541075862 === : === punctuation mark, colon or ellipsis
# -----------------------
# Words is   :  eidgenössische
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  polytechnische
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  Schule
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  )
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2465883113906300949 === -RRB- === right round bracket
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Zürich
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1900
# POS is   :  univ_pos_t.NUM === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  .
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  The
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  following
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  year
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  he
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  acquired
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  Swiss
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  citizenship
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  which
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  416 === dobj === direct object
# Tag is   :  17202369883303991778 === WDT === wh-determiner
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  he
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  kept
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  447 === relcl === relative clause modifier
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  for
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  his
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  440 === poss === possession modifier
# Tag is   :  4062917326063685704 === PRP$ === pronoun, possessive
# -----------------------
# Words is   :  entire
# POS is   :  univ_pos_t.ADJ === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  life
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  .
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  After
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  initially
# POS is   :  univ_pos_t.ADV === ADV === adverb
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  164681854541413346 === RB === adverb
# -----------------------
# Words is   :  struggling
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  438 === pcomp === complement of preposition
# Tag is   :  1534113631682161808 === VBG === verb, gerund or present participle
# -----------------------
# Words is   :  to
# POS is   :  univ_pos_t.PART === PART === particle
# Dep is   :  405 === aux === auxiliary
# Tag is   :  5595707737748328492 === TO === infinitival "to"
# -----------------------
# Words is   :  find
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  450 === xcomp === open clausal complement
# Tag is   :  14200088355797579614 === VB === verb, base form
# -----------------------
# Words is   :  work
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  from
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  1902
# POS is   :  univ_pos_t.NUM === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  to
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1909
# POS is   :  univ_pos_t.NUM === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  he
# POS is   :  univ_pos_t.PRON === PRON === pronoun
# Dep is   :  430 === nsubjpass === nominal subject (passive)
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  was
# POS is   :  univ_pos_t.AUX === AUX === auxiliary
# Dep is   :  406 === auxpass === auxiliary (passive)
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  employed
# POS is   :  univ_pos_t.VERB === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  3822385049556375858 === VBN === verb, past participle
# -----------------------
# Words is   :  as
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  a
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  patent
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  examiner
# POS is   :  univ_pos_t.NOUN === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  at
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  univ_pos_t.DET === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  Swiss
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Patent
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Office
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  in
# POS is   :  univ_pos_t.ADP === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Bern
# POS is   :  univ_pos_t.PROPN === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  .
# POS is   :  univ_pos_t.PUNCT === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
#
# POS is   :  univ_pos_t.SPACE === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  diploma
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  from
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  90 === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  Swiss
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  Federal
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Polytechnic
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  School
# POS is   :  96 === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  (
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  17111077179131903759 === -LRB- === left round bracket
# -----------------------
# Words is   :  German
# POS is   :  96 === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  :
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  11532473245541075862 === : === punctuation mark, colon or ellipsis
# -----------------------
# Words is   :  eidgenössische
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  polytechnische
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Schule
# POS is   :  96 === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  )
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2465883113906300949 === -RRB- === right round bracket
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  in
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Zürich
# POS is   :  96 === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  in
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1900
# POS is   :  93 === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  The
# POS is   :  90 === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  following
# POS is   :  100 === VERB === verb
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  1534113631682161808 === VBG === verb, gerund or present participle
# -----------------------
# Words is   :  year
# POS is   :  92 === NOUN === noun
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  he
# POS is   :  95 === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  acquired
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  Swiss
# POS is   :  84 === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective
# -----------------------
# Words is   :  citizenship
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  which
# POS is   :  90 === DET === determiner
# Dep is   :  416 === dobj === direct object
# Tag is   :  17202369883303991778 === WDT === wh-determiner
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  he
# POS is   :  95 === PRON === pronoun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  kept
# POS is   :  100 === VERB === verb
# Dep is   :  447 === relcl === relative clause modifier
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  for
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  his
# POS is   :  90 === DET === determiner
# Dep is   :  440 === poss === possession modifier
# Tag is   :  4062917326063685704 === PRP$ === pronoun, possessive
# -----------------------
# Words is   :  entire
# POS is   :  84 === ADJ === adjective
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  10554686591937588953 === JJ === adjective
# -----------------------
# Words is   :  life
# POS is   :  92 === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  After
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  initially
# POS is   :  86 === ADV === adverb
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  164681854541413346 === RB === adverb
# -----------------------
# Words is   :  struggling
# POS is   :  100 === VERB === verb
# Dep is   :  438 === pcomp === complement of preposition
# Tag is   :  1534113631682161808 === VBG === verb, gerund or present participle
# -----------------------
# Words is   :  to
# POS is   :  94 === PART === particle
# Dep is   :  405 === aux === auxiliary
# Tag is   :  5595707737748328492 === TO === infinitival "to"
# -----------------------
# Words is   :  find
# POS is   :  100 === VERB === verb
# Dep is   :  450 === xcomp === open clausal complement
# Tag is   :  14200088355797579614 === VB === verb, base form
# -----------------------
# Words is   :  work
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2593208677638477497 === , === punctuation mark, comma
# -----------------------
# Words is   :  from
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  1902
# POS is   :  93 === NUM === numeral
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  to
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  1909
# POS is   :  93 === NUM === numeral
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  8427216679587749980 === CD === cardinal number
# -----------------------
# Words is   :  he
# POS is   :  95 === PRON === pronoun
# Dep is   :  430 === nsubjpass === nominal subject (passive)
# Tag is   :  13656873538139661788 === PRP === pronoun, personal
# -----------------------
# Words is   :  was
# POS is   :  87 === AUX === auxiliary
# Dep is   :  406 === auxpass === auxiliary (passive)
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  employed
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  3822385049556375858 === VBN === verb, past participle
# -----------------------
# Words is   :  as
# POS is   :  98 === SCONJ === subordinating conjunction
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  a
# POS is   :  90 === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  patent
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  examiner
# POS is   :  92 === NOUN === noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  at
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  90 === DET === determiner
# Dep is   :  415 === det === determiner
# Tag is   :  15267657372422890137 === DT === determiner
# -----------------------
# Words is   :  Swiss
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Patent
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  Office
# POS is   :  96 === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  in
# POS is   :  85 === ADP === adposition
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  1292078113972184607 === IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Bern
# POS is   :  96 === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------

# %%
for token in doc1:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# The        DET      DT     determiner
# son        NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# salesman   NOUN     NN     noun, singular or mass
# who        PRON     WP     wh-pronoun, personal
# later      ADV      RB     adverb
# operated   VERB     VBD    verb, past tense
# an         DET      DT     determiner
# electrochemical ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# factory    NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE    _SP    whitespace
# instein    NOUN     NN     noun, singular or mass
# was        AUX      VBD    verb, past tense
# born       VERB     VBN    verb, past participle
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# German     PROPN    NNP    noun, proper singular
# Empire     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# moved      VERB     VBD    verb, past tense
# to         ADP      IN     conjunction, subordinating or preposition
# Switzerland PROPN    NNP    noun, proper singular
# in         ADP      IN     conjunction, subordinating or preposition
# 1895       NUM      CD     cardinal number
# and        CCONJ    CC     conjunction, coordinating
#
#           SPACE    _SP    whitespace
# renounced  VERB     VBD    verb, past tense
# his        PRON     PRP$   pronoun, possessive
# German     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# citizenship NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# 1896       NUM      CD     cardinal number
# .          PUNCT    .      punctuation mark, sentence closer
# Specializing VERB     VBG    verb, gerund or present participle
# in         ADP      IN     conjunction, subordinating or preposition
# physics    NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
#
#           SPACE    _SP    whitespace
# mathematics NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# received   VERB     VBD    verb, past tense
# his        PRON     PRP$   pronoun, possessive
# academic   ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# teaching   NOUN     NN     noun, singular or mass
# diploma    NOUN     NN     noun, singular or mass
# from       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# Swiss      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# Federal    PROPN    NNP    noun, proper singular
# Polytechnic PROPN    NNP    noun, proper singular
# School     PROPN    NNP    noun, proper singular
# (          PUNCT    -LRB-  left round bracket
# German     PROPN    NNP    noun, proper singular
# :          PUNCT    :      punctuation mark, colon or ellipsis
# eidgenössische NOUN     NN     noun, singular or mass
# polytechnische NOUN     NN     noun, singular or mass
# Schule     PROPN    NNP    noun, proper singular
# )          PUNCT    -RRB-  right round bracket
#
#           SPACE    _SP    whitespace
# in         ADP      IN     conjunction, subordinating or preposition
# Zürich     PROPN    NNP    noun, proper singular
# in         ADP      IN     conjunction, subordinating or preposition
# 1900       NUM      CD     cardinal number
# .          PUNCT    .      punctuation mark, sentence closer
# The        DET      DT     determiner
# following  ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# year       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# acquired   VERB     VBD    verb, past tense
# Swiss      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# citizenship NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# which      PRON     WDT    wh-determiner
#
#           SPACE    _SP    whitespace
# he         PRON     PRP    pronoun, personal
# kept       VERB     VBD    verb, past tense
# for        ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# entire     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# life       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
# After      ADP      IN     conjunction, subordinating or preposition
# initially  ADV      RB     adverb
# struggling VERB     VBG    verb, gerund or present participle
# to         PART     TO     infinitival "to"
# find       VERB     VB     verb, base form
# work       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# from       ADP      IN     conjunction, subordinating or preposition
#
#           SPACE    _SP    whitespace
# 1902       NUM      CD     cardinal number
# to         ADP      IN     conjunction, subordinating or preposition
# 1909       NUM      CD     cardinal number
# he         PRON     PRP    pronoun, personal
# was        AUX      VBD    verb, past tense
# employed   VERB     VBN    verb, past participle
# as         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# patent     NOUN     NN     noun, singular or mass
# examiner   NOUN     NN     noun, singular or mass
# at         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# Swiss      PROPN    NNP    noun, proper singular
# Patent     PROPN    NNP    noun, proper singular
# Office     PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# in         ADP      IN     conjunction, subordinating or preposition
# Bern       PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace

# %%
doc = nlp(u'I read book now.')
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBP    verb, non-3rd person singular present

# %%
doc = nlp(u'I read a book on NLP.')
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBD    verb, past tense

# %%
POS_counts = doc1.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 6
# 85. ADP  : 16
# 86. ADV  : 2
# 87. AUX  : 2
# 89. CCONJ: 3
# 90. DET  : 8
# 92. NOUN : 17
# 93. NUM  : 5
# 94. PART : 1
# 95. PRON : 9
# 96. PROPN: 14
# 97. PUNCT: 13
# 100. VERB : 11
# 103. SPACE: 9

# %%
TAG_counts = doc1.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 164681854541413346. RB  : 2
# 783433942507015291. NNS : 1
# 1292078113972184607. IN  : 16
# 1534113631682161808. VBG : 2
# 2465883113906300949. -RRB-: 1
# 2593208677638477497. ,   : 6
# 3822385049556375858. VBN : 2
# 4062917326063685704. PRP$: 3
# 4808651922106831370. WP  : 1
# 5595707737748328492. TO  : 1
# 6893682062797376370. _SP : 9
# 8427216679587749980. CD  : 5
# 10554686591937588953. JJ  : 6
# 11532473245541075862. :   : 1
# 12646065887601541794. .   : 4
# 13656873538139661788. PRP : 4
# 14200088355797579614. VB  : 1
# 15267657372422890137. DT  : 8
# 15308085513773655218. NN  : 16
# 15794550382381185553. NNP : 14
# 17109001835818727656. VBD : 8
# 17111077179131903759. -LRB-: 1
# 17202369883303991778. WDT : 1
# 17571114184892886314. CC  : 3

# %%
DEP_counts = doc1.count_by(spacy.attrs.DEP)

for k,v in sorted(DEP_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 399. advcl: 1
# 400. advmod: 2
# 402. amod: 6
# 403. appos: 3
# 405. aux : 1
# 406. auxpass: 2
# 407. cc  : 3
# 410. conj: 3
# 414. dep : 9
# 415. det : 8
# 416. dobj: 6
# 428. npadvmod: 1
# 429. nsubj: 4
# 430. nsubjpass: 2
# 438. pcomp: 1
# 439. pobj: 15
# 440. poss: 3
# 443. prep: 16
# 445. punct: 13
# 447. relcl: 2
# 450. xcomp: 1
# 7037928807040764755. compound: 10
# 8206900633647566924. ROOT: 4

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger_eng: <urlopen
# [nltk_data]     error [Errno 11001] getaddrinfo failed>
# False

# %%
text = 'Moses supposes his toeses are roses but moses supposes erroneously'

for w , m in nltk.pos_tag(nltk.word_tokenize(text)):
    print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[39], line 3
#       1 text = 'Moses supposes his toeses are roses but moses supposes erroneously'
# ----> 3 for w , m in nltk.pos_tag(nltk.word_tokenize(text)):
#       4     print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\perceptron.py:180, in PerceptronTagger.__init__(self, load, lang, loc)
#     176 self.save_dir = path_join(
#     177     self.TRAINED_TAGGER_PATH, f"{self.TAGGER_NAME}_{self.lang}"
#     178 )
#     179 if load:
# --> 180     self.load_from_json(lang, loc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\perceptron.py:277, in PerceptronTagger.load_from_json(self, lang, loc)
#     274 def load_from_json(self, lang="eng", loc=None):
#     275     # Automatically find path to the tagger if location is not specified.
#     276     if not loc:
# --> 277         loc = find(f"taggers/averaged_perceptron_tagger_{lang}")
#     279     def load_param(json_file):
#     280         with open(path_join(loc, json_file)) as fin:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng
#
#   Searched in:
#     - 'C:\\Users\\AT/nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\share\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\lib\\nltk_data'
#     - 'C:\\Users\\AT\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
text = '''
Thomas Gradgrind, sir.  A man of realities.  A man of facts and calculations.  A man who proceeds upon the principle that
two and two are four, and nothing over, and who is not to be talked i
nto allowing for anything over.  Thomas Gradgrind, 
sir—peremptorily Thomas—Thomas Gradgrind.  With a rule and a pair of scales, and the multiplication table always in his pocket, 
sir, ready to weigh and measure any parcel of human nature, and tell you exactly what it comes to.  It is a mere question of
figures, a case of simple arithmetic.  You might hope to get some other nonsensical belief into the head of George Gradgrind, or Augustus Gradgrind, or John Gradgrind, or Joseph Gradgrind (all supposititious, non-existent persons), but into the head of Thomas Gradgrind—no, sir!

In such terms Mr. Gradgrind always mentally introduced himself, whether to his private circle of acquaintance, or to the public in general.  In such terms, no doubt, substituting the words ‘boys and girls,’ for ‘sir,’ Thomas Gradgrind now presented Thomas Gradgrind to the little pitchers before him, who were to be filled so full of facts.
'''

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(text)
tokenized = custom_sent_tokenizer.tokenize(text)
tokenized[:10]
# Out:
# ['\nThomas Gradgrind, sir.',
#  'A man of realities.',
#  'A man of facts and calculations.',
#  'A man who proceeds upon the principle that\ntwo and two are four, and nothing over, and who is not to be talked i\nnto allowing for anything over.',
#  'Thomas Gradgrind, \nsir—peremptorily Thomas—Thomas Gradgrind.',
#  'With a rule and a pair of scales, and the multiplication table always in his pocket, \nsir, ready to weigh and measure any parcel of human nature, and tell you exactly what it comes to.',
#  'It is a mere question of\nfigures, a case of simple arithmetic.',
#  'You might hope to get some other nonsensical belief into the head of George Gradgrind, or Augustus Gradgrind, or John Gradgrind, or Joseph Gradgrind (all supposititious, non-existent persons), but into the head of Thomas Gradgrind—no, sir!',
#  'In such terms Mr. Gradgrind always mentally introduced himself, whether to his private circle of acquaintance, or to the public in general.',
#  'In such terms, no doubt, substituting the words ‘boys and girls,’ for ‘sir,’ Thomas Gradgrind now presented Thomas Gradgrind to the little pitchers before him, who were to be filled so full of facts.']

# %%
for i in tokenized[:5]:
    for w , m in nltk.pos_tag(nltk.word_tokenize(i)):
        print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
    print('-----------------------------------------------')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[42], line 2
#       1 for i in tokenized[:5]:
# ----> 2     for w , m in nltk.pos_tag(nltk.word_tokenize(i)):
#       3         print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
#       4     print('-----------------------------------------------')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\perceptron.py:180, in PerceptronTagger.__init__(self, load, lang, loc)
#     176 self.save_dir = path_join(
#     177     self.TRAINED_TAGGER_PATH, f"{self.TAGGER_NAME}_{self.lang}"
#     178 )
#     179 if load:
# --> 180     self.load_from_json(lang, loc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tag\perceptron.py:277, in PerceptronTagger.load_from_json(self, lang, loc)
#     274 def load_from_json(self, lang="eng", loc=None):
#     275     # Automatically find path to the tagger if location is not specified.
#     276     if not loc:
# --> 277         loc = find(f"taggers/averaged_perceptron_tagger_{lang}")
#     279     def load_param(json_file):
#     280         with open(path_join(loc, json_file)) as fin:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng
#
#   Searched in:
#     - 'C:\\Users\\AT/nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\share\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\lib\\nltk_data'
#     - 'C:\\Users\\AT\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
import re           
train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource state_union not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('state_union')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/state_union.zip/state_union/
#
#   Searched in:
#     - 'C:\\Users\\AT/nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\share\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\lib\\nltk_data'
#     - 'C:\\Users\\AT\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[43], line 2
#       1 import re
# ----> 2 train_text = state_union.raw("2005-GWBush.txt")
#       3 sample_text = state_union.raw("2006-GWBush.txt")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource state_union not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('state_union')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/state_union
#
#   Searched in:
#     - 'C:\\Users\\AT/nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\share\\nltk_data'
#     - 'C:\\Users\\AT\\Documents\\Project_AI\\Surah-Fatiha-NLP-Dev\\nlp_dl_env\\lib\\nltk_data'
#     - 'C:\\Users\\AT\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
train_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 train_text
#
# NameError: name 'train_text' is not defined

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)
tokenized[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
#       2 tokenized = custom_sent_tokenizer.tokenize(sample_text)
#       3 tokenized[:5]
#
# NameError: name 'train_text' is not defined

# %%
for i in tokenized[:5]:
    for w , m in nltk.pos_tag(nltk.word_tokenize(i)):
        print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
    print('-----------------------------------------------')
# Out:
# word : (PRESIDENT), type : (NNP) , means :  (noun, proper singular)
# word : (GEORGE), type : (NNP) , means :  (noun, proper singular)
# word : (W.), type : (NNP) , means :  (noun, proper singular)
# word : (BUSH), type : (NNP) , means :  (noun, proper singular)
# word : ('S), type : (POS) , means :  (possessive ending)
# word : (ADDRESS), type : (NNP) , means :  (noun, proper singular)
# word : (BEFORE), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (A), type : (NNP) , means :  (noun, proper singular)
# word : (JOINT), type : (NNP) , means :  (noun, proper singular)
# word : (SESSION), type : (NNP) , means :  (noun, proper singular)
# word : (OF), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (THE), type : (NNP) , means :  (noun, proper singular)
# word : (CONGRESS), type : (NNP) , means :  (noun, proper singular)
# word : (ON), type : (NNP) , means :  (noun, proper singular)
# word : (THE), type : (NNP) , means :  (noun, proper singular)
# word : (STATE), type : (NNP) , means :  (noun, proper singular)
# word : (OF), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (THE), type : (NNP) , means :  (noun, proper singular)
# word : (UNION), type : (NNP) , means :  (noun, proper singular)
# word : (January), type : (NNP) , means :  (noun, proper singular)
# word : (31), type : (CD) , means :  (cardinal number)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (2006), type : (CD) , means :  (cardinal number)
# word : (THE), type : (NNP) , means :  (noun, proper singular)
# word : (PRESIDENT), type : (NNP) , means :  (noun, proper singular)
# word : (:), type : (:) , means :  (punctuation mark, colon or ellipsis)
# word : (Thank), type : (NNP) , means :  (noun, proper singular)
# word : (you), type : (PRP) , means :  (pronoun, personal)
# word : (all), type : (DT) , means :  (determiner)
# word : (.), type : (.) , means :  (punctuation mark, sentence closer)
# -----------------------------------------------
# word : (Mr.), type : (NNP) , means :  (noun, proper singular)
# word : (Speaker), type : (NNP) , means :  (noun, proper singular)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (Vice), type : (NNP) , means :  (noun, proper singular)
# word : (President), type : (NNP) , means :  (noun, proper singular)
# word : (Cheney), type : (NNP) , means :  (noun, proper singular)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (members), type : (NNS) , means :  (noun, plural)
# word : (of), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (Congress), type : (NNP) , means :  (noun, proper singular)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (members), type : (NNS) , means :  (noun, plural)
# word : (of), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (Supreme), type : (NNP) , means :  (noun, proper singular)
# word : (Court), type : (NNP) , means :  (noun, proper singular)
# word : (and), type : (CC) , means :  (conjunction, coordinating)
# word : (diplomatic), type : (JJ) , means :  (adjective)
# word : (corps), type : (NN) , means :  (noun, singular or mass)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (distinguished), type : (JJ) , means :  (adjective)
# word : (guests), type : (NNS) , means :  (noun, plural)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (and), type : (CC) , means :  (conjunction, coordinating)
# word : (fellow), type : (JJ) , means :  (adjective)
# word : (citizens), type : (NNS) , means :  (noun, plural)
# word : (:), type : (:) , means :  (punctuation mark, colon or ellipsis)
# word : (Today), type : (VB) , means :  (verb, base form)
# word : (our), type : (PRP$) , means :  (pronoun, possessive)
# word : (nation), type : (NN) , means :  (noun, singular or mass)
# word : (lost), type : (VBD) , means :  (verb, past tense)
# word : (a), type : (DT) , means :  (determiner)
# word : (beloved), type : (VBN) , means :  (verb, past participle)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (graceful), type : (JJ) , means :  (adjective)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (courageous), type : (JJ) , means :  (adjective)
# word : (woman), type : (NN) , means :  (noun, singular or mass)
# word : (who), type : (WP) , means :  (wh-pronoun, personal)
# word : (called), type : (VBD) , means :  (verb, past tense)
# word : (America), type : (NNP) , means :  (noun, proper singular)
# word : (to), type : (TO) , means :  (infinitival "to")
# word : (its), type : (PRP$) , means :  (pronoun, possessive)
# word : (founding), type : (NN) , means :  (noun, singular or mass)
# word : (ideals), type : (NNS) , means :  (noun, plural)
# word : (and), type : (CC) , means :  (conjunction, coordinating)
# word : (carried), type : (VBD) , means :  (verb, past tense)
# word : (on), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (a), type : (DT) , means :  (determiner)
# word : (noble), type : (JJ) , means :  (adjective)
# word : (dream), type : (NN) , means :  (noun, singular or mass)
# word : (.), type : (.) , means :  (punctuation mark, sentence closer)
# -----------------------------------------------
# word : (Tonight), type : (NN) , means :  (noun, singular or mass)
# word : (we), type : (PRP) , means :  (pronoun, personal)
# word : (are), type : (VBP) , means :  (verb, non-3rd person singular present)
# word : (comforted), type : (VBN) , means :  (verb, past participle)
# word : (by), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (hope), type : (NN) , means :  (noun, singular or mass)
# word : (of), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (a), type : (DT) , means :  (determiner)
# word : (glad), type : (JJ) , means :  (adjective)
# word : (reunion), type : (NN) , means :  (noun, singular or mass)
# word : (with), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (husband), type : (NN) , means :  (noun, singular or mass)
# word : (who), type : (WP) , means :  (wh-pronoun, personal)
# word : (was), type : (VBD) , means :  (verb, past tense)
# word : (taken), type : (VBN) , means :  (verb, past participle)
# word : (so), type : (RB) , means :  (adverb)
# word : (long), type : (RB) , means :  (adverb)
# word : (ago), type : (RB) , means :  (adverb)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (and), type : (CC) , means :  (conjunction, coordinating)
# word : (we), type : (PRP) , means :  (pronoun, personal)
# word : (are), type : (VBP) , means :  (verb, non-3rd person singular present)
# word : (grateful), type : (JJ) , means :  (adjective)
# word : (for), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (good), type : (JJ) , means :  (adjective)
# word : (life), type : (NN) , means :  (noun, singular or mass)
# word : (of), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (Coretta), type : (NNP) , means :  (noun, proper singular)
# word : (Scott), type : (NNP) , means :  (noun, proper singular)
# word : (King), type : (NNP) , means :  (noun, proper singular)
# word : (.), type : (.) , means :  (punctuation mark, sentence closer)
# -----------------------------------------------
# word : ((), type : (() , means :  (None)
# word : (Applause), type : (NNP) , means :  (noun, proper singular)
# word : (.), type : (.) , means :  (punctuation mark, sentence closer)
# word : ()), type : ()) , means :  (None)
# -----------------------------------------------
# word : (President), type : (NNP) , means :  (noun, proper singular)
# word : (George), type : (NNP) , means :  (noun, proper singular)
# word : (W.), type : (NNP) , means :  (noun, proper singular)
# word : (Bush), type : (NNP) , means :  (noun, proper singular)
# word : (reacts), type : (VBZ) , means :  (verb, 3rd person singular present)
# word : (to), type : (TO) , means :  (infinitival "to")
# word : (applause), type : (VB) , means :  (verb, base form)
# word : (during), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (his), type : (PRP$) , means :  (pronoun, possessive)
# word : (State), type : (NNP) , means :  (noun, proper singular)
# word : (of), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (Union), type : (NNP) , means :  (noun, proper singular)
# word : (Address), type : (NNP) , means :  (noun, proper singular)
# word : (at), type : (IN) , means :  (conjunction, subordinating or preposition)
# word : (the), type : (DT) , means :  (determiner)
# word : (Capitol), type : (NNP) , means :  (noun, proper singular)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (Tuesday), type : (NNP) , means :  (noun, proper singular)
# word : (,), type : (,) , means :  (punctuation mark, comma)
# word : (Jan), type : (NNP) , means :  (noun, proper singular)
# word : (.), type : (.) , means :  (punctuation mark, sentence closer)
# -----------------------------------------------

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp('''ضمت مؤلفات الخوارزمي كتاب الجمع والتفريق
في الحساب الهندي، وكتاب رسم الربع المعمور، وكتاب تقويم البلدان، وكتاب العمل بالأسطرلاب، 
وكتاب "صورة الأرض " الذي اعتمد فيه على كتاب المجسطي لبطليموس مع إضافات وشروح
وتعليقات، وأعاد كتابة كتاب الفلك الهندي المعروف باسم "السند هند الكبير" الذي ترجم إلى اللغة
العربية زمن الخليفة المنصور فأعاد الخوارزمي كتابته وأضاف إليه وسمي كتابه "السند هند الصغير".

وقد عرض في كتاب المختصر في حساب الجبر والمقابلة أول حل منهجي
للمعادلات الخطية والمعادلات التربيعية مستعملا في ذلك الطريقة المعروفة باسم إكمال المربع. ويعتبر مؤسس علم الجبر،
(اللقب الذي يتقاسمه مع ديوفانتوس) في القرن الثاني عشر، ولقد قدمت ترجمات اللاتينية عن حسابه على الأرقام الهندية، 
النظام العشري إلى العالم الغربي. نقح الخوارزمي كتاب الجغرافيا لكلاوديوس بطليموس وكتب في علم الفلك والتنجيم.
''')


for token in doc1:
    print('Words is   : ' , token.text)
    print('POS is   : ' , token.pos ,'===',token.pos_  , '===', spacy.explain(token.pos_))
    print('Dep is   : ' , token.dep , '===',token.dep_, '===', spacy.explain(token.dep_))
    print('Tag is   : ' , token.tag , '===',token.tag_, '===', spacy.explain(token.tag_))
    print('-----------------------')
# Out:
# Words is   :  ضمت
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مؤلفات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجمع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والتفريق
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الحساب
# POS is   :  100 === VERB === verb
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  9188597074677201817 === VBP === verb, non-3rd person singular present
# -----------------------
# Words is   :  الهندي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  رسم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الربع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المعمور
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  تقويم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  البلدان
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  445 === punct === punctuation
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العمل
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  بالأسطرلاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  445 === punct === punctuation
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  صورة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الأرض
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اعتمد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  فيه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  على
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المجسطي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  لبطليموس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إضافات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وشروح
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  وتعليقات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  445 === punct === punctuation
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وأعاد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الفلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الهندي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المعروف
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  باسم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  السند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  هند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الكبير
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ترجم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إلى
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اللغة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  العربية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  زمن
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخليفة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المنصور
# POS is   :  96 === PROPN === proper noun
# Dep is   :  408 === ccomp === clausal complement
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  فأعاد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابته
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  783433942507015291 === NNS === noun, plural
# -----------------------
# Words is   :  وأضاف
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إليه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وسمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  410 === conj === conjunct
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  السند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  هند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الصغير
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  783433942507015291 === NNS === noun, plural
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  وقد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  عرض
# POS is   :  96 === PROPN === proper noun
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المختصر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حساب
# POS is   :  100 === VERB === verb
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  9188597074677201817 === VBP === verb, non-3rd person singular present
# -----------------------
# Words is   :  الجبر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والمقابلة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  أول
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حل
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  منهجي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  للمعادلات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخطية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والمعادلات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  التربيعية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مستعملا
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  11233576250605462493 === NNPS === noun, proper plural
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ذلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الطريقة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المعروفة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  باسم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إكمال
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المربع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  ويعتبر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مؤسس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  علم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجبر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  439 === pobj === object of preposition
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  (
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  17111077179131903759 === -LRB- === left round bracket
# -----------------------
# Words is   :  اللقب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  يتقاسمه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ديوفانتوس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  )
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2465883113906300949 === -RRB- === right round bracket
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  القرن
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  الثاني
# POS is   :  96 === PROPN === proper noun
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  عشر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ولقد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  قدمت
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ترجمات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اللاتينية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  عن
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حسابه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  على
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الأرقام
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الهندية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  445 === punct === punctuation
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------
# Words is   :  النظام
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العشري
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إلى
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العالم
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  الغربي
# POS is   :  86 === ADV === adverb
# Dep is   :  416 === dobj === direct object
# Tag is   :  164681854541413346 === RB === adverb
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  نقح
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجغرافيا
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  لكلاوديوس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  بطليموس
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  9188597074677201817 === VBP === verb, non-3rd person singular present
# -----------------------
# Words is   :  وكتب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  علم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الفلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والتنجيم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === None
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  0 ===  === None
# Tag is   :  6893682062797376370 === _SP === None
# -----------------------

# %%
for token in doc1:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# ضمت        PROPN    NNP    noun, proper singular
# مؤلفات     PROPN    NNP    noun, proper singular
# الخوارزمي  PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# الجمع      PROPN    NNP    noun, proper singular
# والتفريق   PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# في         PROPN    NNP    noun, proper singular
# الحساب     VERB     VBP    verb, non-3rd person singular present
# الهندي     PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# رسم        PROPN    NNP    noun, proper singular
# الربع      PROPN    NNP    noun, proper singular
# المعمور    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# تقويم      PROPN    NNP    noun, proper singular
# البلدان    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# العمل      PROPN    NNP    noun, proper singular
# بالأسطرلاب PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# وكتاب      PROPN    NNP    noun, proper singular
# "          PUNCT    ``     opening quotation mark
# صورة       PROPN    NNP    noun, proper singular
# الأرض      VERB     VBD    verb, past tense
# "          PUNCT    ''     closing quotation mark
# الذي       PROPN    NNP    noun, proper singular
# اعتمد      PROPN    NNP    noun, proper singular
# فيه        PROPN    NNP    noun, proper singular
# على        PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# المجسطي    PROPN    NNP    noun, proper singular
# لبطليموس   PROPN    NNP    noun, proper singular
# مع         PROPN    NNP    noun, proper singular
# إضافات     PROPN    NNP    noun, proper singular
# وشروح      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# وتعليقات   PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وأعاد      PROPN    NNP    noun, proper singular
# كتابة      PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# الفلك      PROPN    NNP    noun, proper singular
# الهندي     PROPN    NNP    noun, proper singular
# المعروف    PROPN    NNP    noun, proper singular
# باسم       PROPN    NNP    noun, proper singular
# "          PUNCT    ``     opening quotation mark
# السند      PROPN    NNP    noun, proper singular
# هند        PROPN    NNP    noun, proper singular
# الكبير     PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
# الذي       PROPN    NNP    noun, proper singular
# ترجم       PROPN    NNP    noun, proper singular
# إلى        PROPN    NNP    noun, proper singular
# اللغة      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# العربية    PROPN    NNP    noun, proper singular
# زمن        PROPN    NNP    noun, proper singular
# الخليفة    PROPN    NNP    noun, proper singular
# المنصور    PROPN    NNP    noun, proper singular
# فأعاد      PROPN    NNP    noun, proper singular
# الخوارزمي  PROPN    NNP    noun, proper singular
# كتابته     NOUN     NNS    noun, plural
# وأضاف      PROPN    NNP    noun, proper singular
# إليه       PROPN    NNP    noun, proper singular
# وسمي       PROPN    NNP    noun, proper singular
# كتابه      PROPN    NNP    noun, proper singular
# "          PUNCT    ``     opening quotation mark
# السند      PROPN    NNP    noun, proper singular
# هند        PROPN    NNP    noun, proper singular
# الصغير     NOUN     NNS    noun, plural
# "          PUNCT    ''     closing quotation mark
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    None
# وقد        PROPN    NNP    noun, proper singular
# عرض        PROPN    NNP    noun, proper singular
# في         PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# المختصر    PROPN    NNP    noun, proper singular
# في         PROPN    NNP    noun, proper singular
# حساب       VERB     VBP    verb, non-3rd person singular present
# الجبر      PROPN    NNP    noun, proper singular
# والمقابلة  PROPN    NNP    noun, proper singular
# أول        PROPN    NNP    noun, proper singular
# حل         PROPN    NNP    noun, proper singular
# منهجي      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# للمعادلات  PROPN    NNP    noun, proper singular
# الخطية     PROPN    NNP    noun, proper singular
# والمعادلات PROPN    NNP    noun, proper singular
# التربيعية  PROPN    NNP    noun, proper singular
# مستعملا    PROPN    NNPS   noun, proper plural
# في         PROPN    NNP    noun, proper singular
# ذلك        PROPN    NNP    noun, proper singular
# الطريقة    PROPN    NNP    noun, proper singular
# المعروفة   PROPN    NNP    noun, proper singular
# باسم       PROPN    NNP    noun, proper singular
# إكمال      PROPN    NNP    noun, proper singular
# المربع     PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
# ويعتبر     PROPN    NNP    noun, proper singular
# مؤسس       PROPN    NNP    noun, proper singular
# علم        PROPN    NNP    noun, proper singular
# الجبر      PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# (          PUNCT    -LRB-  left round bracket
# اللقب      PROPN    NNP    noun, proper singular
# الذي       PROPN    NNP    noun, proper singular
# يتقاسمه    PROPN    NNP    noun, proper singular
# مع         PROPN    NNP    noun, proper singular
# ديوفانتوس  PROPN    NNP    noun, proper singular
# )          PUNCT    -RRB-  right round bracket
# في         PROPN    NNP    noun, proper singular
# القرن      VERB     VBD    verb, past tense
# الثاني     PROPN    NNP    noun, proper singular
# عشر        PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# ولقد       PROPN    NNP    noun, proper singular
# قدمت       PROPN    NNP    noun, proper singular
# ترجمات     PROPN    NNP    noun, proper singular
# اللاتينية  PROPN    NNP    noun, proper singular
# عن         PROPN    NNP    noun, proper singular
# حسابه      PROPN    NNP    noun, proper singular
# على        PROPN    NNP    noun, proper singular
# الأرقام    PROPN    NNP    noun, proper singular
# الهندية    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    None
# النظام     PROPN    NNP    noun, proper singular
# العشري     PROPN    NNP    noun, proper singular
# إلى        PROPN    NNP    noun, proper singular
# العالم     NOUN     NN     noun, singular or mass
# الغربي     ADV      RB     adverb
# .          PUNCT    .      punctuation mark, sentence closer
# نقح        PROPN    NNP    noun, proper singular
# الخوارزمي  PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# الجغرافيا  PROPN    NNP    noun, proper singular
# لكلاوديوس  PROPN    NNP    noun, proper singular
# بطليموس    VERB     VBP    verb, non-3rd person singular present
# وكتب       PROPN    NNP    noun, proper singular
# في         PROPN    NNP    noun, proper singular
# علم        PROPN    NNP    noun, proper singular
# الفلك      PROPN    NNP    noun, proper singular
# والتنجيم   PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    None

# %%
POS_counts = doc1.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{5}}: {v}')
# Out:
# 86. ADV  : 1
# 92. NOUN : 3
# 96. PROPN: 122
# 97. PUNCT: 12
# 100. VERB : 5
# 103. SPACE: 9

# %%
TAG_counts = doc1.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 164681854541413346. RB  : 1
# 783433942507015291. NNS : 2
# 2465883113906300949. -RRB-: 1
# 4969857429396651903. ``  : 3
# 6893682062797376370. _SP : 9
# 9188597074677201817. VBP : 3
# 11233576250605462493. NNPS: 1
# 12646065887601541794. .   : 4
# 14143520107006108953. ''  : 3
# 15308085513773655218. NN  : 1
# 15794550382381185553. NNP : 121
# 17109001835818727656. VBD : 2
# 17111077179131903759. -LRB-: 1

# %%
DEP_counts = doc1.count_by(spacy.attrs.DEP)

for k,v in sorted(DEP_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 0.     : 9
# 400. advmod: 2
# 402. amod: 8
# 408. ccomp: 1
# 410. conj: 1
# 414. dep : 2
# 416. dobj: 7
# 426. nmod: 5
# 428. npadvmod: 2
# 429. nsubj: 15
# 439. pobj: 1
# 445. punct: 16
# 7037928807040764755. compound: 55
# 8206900633647566924. ROOT: 28
