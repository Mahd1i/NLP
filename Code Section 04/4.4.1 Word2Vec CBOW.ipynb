# %% [markdown]
# Original Notebook
#
# https://www.kaggle.com/alincijov/continuous-bag-of-words-cbow-numpy-for-beginners

# %% [markdown]
# ### Imports

# %%
import re
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
sentences = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %% [markdown]
# ### Clean Data

# %%
# remove special characters
sentences = re.sub('[^A-Za-z0-9]+', ' ', sentences)
sentences
# Out:
# 'We are about to study the idea of a computational process Computational processes are abstract beings that inhabit computers As they evolve processes manipulate other abstract things called data The evolution of a process is directed by a pattern of rules called a program People create programs to direct processes In effect we conjure the spirits of the computer with our spells '

# %%
# remove 1 letter words
sentences = re.sub(r'(?:^| )\w(?:$| )', ' ', sentences).strip()
sentences
# Out:
# 'We are about to study the idea of computational process Computational processes are abstract beings that inhabit computers As they evolve processes manipulate other abstract things called data The evolution of process is directed by pattern of rules called program People create programs to direct processes In effect we conjure the spirits of the computer with our spells'

# %%
# lower all characters
sentences = sentences.lower()
sentences
# Out:
# 'we are about to study the idea of computational process computational processes are abstract beings that inhabit computers as they evolve processes manipulate other abstract things called data the evolution of process is directed by pattern of rules called program people create programs to direct processes in effect we conjure the spirits of the computer with our spells'

# %% [markdown]
# ### Vocabulary

# %%
words = sentences.split()
words
# Out:
# ['we',
#  'are',
#  'about',
#  'to',
#  'study',
#  'the',
#  'idea',
#  'of',
#  'computational',
#  'process',
#  'computational',
#  'processes',
#  'are',
#  'abstract',
#  'beings',
#  'that',
#  'inhabit',
#  'computers',
#  'as',
#  'they',
#  'evolve',
#  'processes',
#  'manipulate',
#  'other',
#  'abstract',
#  'things',
#  'called',
#  'data',
#  'the',
#  'evolution',
#  'of',
#  'process',
#  'is',
#  'directed',
#  'by',
#  'pattern',
#  'of',
#  'rules',
#  'called',
#  'program',
#  'people',
#  'create',
#  'programs',
#  'to',
#  'direct',
#  'processes',
#  'in',
#  'effect',
#  'we',
#  'conjure',
#  'the',
#  'spirits',
#  'of',
#  'the',
#  'computer',
#  'with',
#  'our',
#  'spells']

# %%
vocab = set(words)
vocab
# Out:
# {'about',
#  'abstract',
#  'are',
#  'as',
#  'beings',
#  'by',
#  'called',
#  'computational',
#  'computer',
#  'computers',
#  'conjure',
#  'create',
#  'data',
#  'direct',
#  'directed',
#  'effect',
#  'evolution',
#  'evolve',
#  'idea',
#  'in',
#  'inhabit',
#  'is',
#  'manipulate',
#  'of',
#  'other',
#  'our',
#  'pattern',
#  'people',
#  'process',
#  'processes',
#  'program',
#  'programs',
#  'rules',
#  'spells',
#  'spirits',
#  'study',
#  'that',
#  'the',
#  'they',
#  'things',
#  'to',
#  'we',
#  'with'}

# %%
vocab_size = len(vocab)
embed_dim = 10
context_size = 2

# %% [markdown]
# ### Dictionaries for vocab

# %%
word_to_ix = {word: i for i, word in enumerate(vocab)}
word_to_ix
# Out:
# {'rules': 0,
#  'that': 1,
#  'abstract': 2,
#  'process': 3,
#  'program': 4,
#  'computational': 5,
#  'inhabit': 6,
#  'we': 7,
#  'other': 8,
#  'data': 9,
#  'direct': 10,
#  'computers': 11,
#  'create': 12,
#  'of': 13,
#  'effect': 14,
#  'computer': 15,
#  'called': 16,
#  'things': 17,
#  'pattern': 18,
#  'the': 19,
#  'beings': 20,
#  'are': 21,
#  'they': 22,
#  'as': 23,
#  'people': 24,
#  'spells': 25,
#  'is': 26,
#  'in': 27,
#  'manipulate': 28,
#  'evolution': 29,
#  'our': 30,
#  'to': 31,
#  'evolve': 32,
#  'spirits': 33,
#  'idea': 34,
#  'study': 35,
#  'about': 36,
#  'directed': 37,
#  'with': 38,
#  'by': 39,
#  'conjure': 40,
#  'programs': 41,
#  'processes': 42}

# %%
ix_to_word = {i: word for i, word in enumerate(vocab)}
ix_to_word
# Out:
# {0: 'rules',
#  1: 'that',
#  2: 'abstract',
#  3: 'process',
#  4: 'program',
#  5: 'computational',
#  6: 'inhabit',
#  7: 'we',
#  8: 'other',
#  9: 'data',
#  10: 'direct',
#  11: 'computers',
#  12: 'create',
#  13: 'of',
#  14: 'effect',
#  15: 'computer',
#  16: 'called',
#  17: 'things',
#  18: 'pattern',
#  19: 'the',
#  20: 'beings',
#  21: 'are',
#  22: 'they',
#  23: 'as',
#  24: 'people',
#  25: 'spells',
#  26: 'is',
#  27: 'in',
#  28: 'manipulate',
#  29: 'evolution',
#  30: 'our',
#  31: 'to',
#  32: 'evolve',
#  33: 'spirits',
#  34: 'idea',
#  35: 'study',
#  36: 'about',
#  37: 'directed',
#  38: 'with',
#  39: 'by',
#  40: 'conjure',
#  41: 'programs',
#  42: 'processes'}

# %% [markdown]
# ### Data bags

# %%
# data - [(context), target]


#  """We are about to study the idea of a computational process.
# Computational processes are abstract beings that inhabit computers.
# As they evolve, processes manipulate other abstract things called data.
# The evolution of a process is directed by a pattern of rules
# called a program. People create programs to direct processes. In effect,
# we conjure the spirits of the computer with our spells."""


data = []
for i in range(2, len(words) - 2):
    context = [words[i - 2], words[i - 1], words[i + 1], words[i + 2]]
    target = words[i]
    data.append((context, target))
print(data[:5])
# Out:
# [(['we', 'are', 'to', 'study'], 'about'), (['are', 'about', 'study', 'the'], 'to'), (['about', 'to', 'the', 'idea'], 'study'), (['to', 'study', 'idea', 'of'], 'the'), (['study', 'the', 'of', 'computational'], 'idea')]

# %% [markdown]
# ### Embeddings

# %%
embeddings =  np.random.random_sample((vocab_size, embed_dim))
print(embeddings.shape)
embeddings
# Out:
# (43, 10)
# array([[7.23304633e-01, 9.27350117e-03, 5.10724343e-01, 5.58838719e-01,
#         7.52482768e-01, 9.46844717e-01, 5.25569592e-01, 4.53169549e-01,
#         6.98058362e-01, 4.35221719e-01],
#        [5.80841959e-01, 5.22753521e-01, 2.48135757e-01, 1.38123835e-01,
#         4.64363780e-01, 6.23803220e-01, 5.48716291e-01, 2.94861549e-01,
#         9.95965810e-02, 3.89173963e-01],
#        [7.79126980e-01, 9.06222891e-01, 4.79506950e-02, 1.11860824e-01,
#         5.09711233e-01, 7.74688344e-01, 8.31489668e-01, 6.39775245e-01,
#         2.84701128e-01, 2.26652051e-01],
#        [4.66974809e-03, 9.40778307e-01, 6.36922663e-01, 4.67201403e-01,
#         1.16061532e-01, 9.49810848e-01, 5.17004878e-01, 2.60963881e-01,
#         6.39715389e-01, 7.51603275e-02],
#        [8.19135527e-01, 6.58177290e-01, 1.24734156e-01, 4.07280402e-01,
#         3.77352078e-01, 7.02686441e-01, 3.14736686e-01, 3.65704651e-01,
#         9.81605506e-01, 2.17364566e-01],
#        [3.31882624e-01, 6.96500778e-02, 5.68030223e-01, 5.84639742e-02,
#         1.56463820e-03, 1.02512998e-01, 8.87475843e-01, 8.12553044e-01,
#         9.32567115e-01, 2.80430699e-01],
#        [1.53652477e-04, 6.09720801e-01, 6.17413740e-01, 7.04774444e-01,
#         2.58704541e-01, 2.76868935e-01, 5.01467635e-01, 5.04095023e-01,
#         2.29457955e-01, 9.23009282e-02],
#        [7.43254743e-01, 5.42528273e-01, 8.03727384e-01, 8.53911349e-01,
#         1.04070274e-01, 3.39180872e-01, 6.24756685e-01, 4.38464215e-01,
#         2.22873056e-01, 6.22815729e-01],
#        [7.15954699e-03, 8.36000259e-01, 1.36943850e-01, 3.00383881e-01,
#         4.86376877e-01, 5.68530249e-01, 2.19736336e-01, 5.93329312e-01,
#         3.13766500e-01, 8.13589211e-02],
#        [8.70194419e-01, 2.11451393e-01, 1.34023476e-01, 1.02183697e-01,
#         6.49183750e-01, 6.58697051e-01, 6.22437504e-01, 2.49033115e-02,
#         8.85377709e-01, 5.09113403e-01],
#        [1.06506432e-01, 7.93137092e-01, 2.97323821e-01, 6.61350862e-01,
#         3.69408924e-01, 6.05180537e-01, 5.08442829e-02, 8.92917605e-01,
#         8.69721036e-01, 4.44815157e-01],
#        [4.89925867e-01, 4.47354017e-01, 1.58918011e-01, 3.87417341e-01,
#         7.13364610e-01, 9.64128520e-01, 5.05190539e-01, 9.85530863e-01,
#         3.83444015e-01, 2.52589312e-01],
#        [1.36183329e-02, 3.36518485e-01, 3.10492464e-01, 8.32591435e-01,
#         6.59518428e-01, 7.39790383e-01, 9.54417159e-01, 9.55857040e-01,
#         2.79124994e-01, 4.71403610e-01],
#        [5.85167411e-02, 6.49794271e-01, 9.50803196e-01, 6.92939341e-01,
#         9.42847762e-01, 7.26682649e-02, 8.40540387e-02, 9.86084437e-01,
#         4.27563399e-01, 7.92827326e-01],
#        [8.54691526e-01, 7.93704873e-01, 3.42390250e-01, 4.64826187e-01,
#         7.01446454e-01, 3.86179740e-01, 6.47955585e-01, 3.18491555e-01,
#         7.20098789e-01, 7.20787754e-01],
#        [2.47020127e-01, 5.60687112e-01, 7.91344351e-01, 2.36640990e-02,
#         6.02686066e-01, 5.24102529e-01, 8.93946614e-01, 4.28401730e-01,
#         2.89686141e-01, 6.15907349e-01],
#        [2.18269135e-01, 4.29480137e-01, 5.84692074e-01, 1.01764460e-01,
#         2.62253284e-02, 7.49232210e-02, 1.66544421e-01, 3.99914253e-01,
#         3.15952998e-01, 2.63579278e-03],
#        [4.02346922e-01, 3.72601068e-01, 6.18579781e-01, 8.01561303e-01,
#         7.87483636e-01, 9.34133216e-01, 9.30248364e-01, 8.10247841e-01,
#         1.18937787e-01, 5.95299358e-01],
#        [3.05535106e-01, 3.91842312e-01, 2.05189208e-01, 6.81909801e-01,
#         7.07923465e-01, 1.11109809e-01, 7.67100154e-01, 4.14417470e-01,
#         3.11111295e-01, 6.02161930e-01],
#        [5.33445174e-01, 7.29114167e-01, 5.90328305e-01, 4.79300708e-01,
#         7.92360607e-01, 4.97917743e-01, 2.63196779e-02, 1.15671238e-01,
#         9.33178865e-01, 9.15626132e-01],
#        [4.59270005e-01, 9.18049954e-01, 4.60387198e-02, 9.81925536e-01,
#         4.73495896e-01, 2.65523019e-01, 5.31117629e-01, 8.13036929e-01,
#         6.56848283e-01, 3.99541901e-01],
#        [4.63272907e-01, 2.63544523e-01, 7.51976043e-01, 9.32999825e-01,
#         4.22197757e-01, 1.06734228e-01, 8.48155106e-01, 3.96739376e-01,
#         3.88471091e-01, 2.10098618e-01],
#        [1.58412110e-01, 9.19910019e-01, 5.83925092e-01, 2.65340266e-01,
#         1.52610037e-01, 7.55577439e-01, 7.07507589e-01, 5.27790656e-01,
#         6.32208961e-01, 8.11631940e-01],
#        [5.39442946e-01, 5.13556721e-01, 7.63628697e-01, 4.66935419e-01,
#         2.88690870e-02, 3.46613157e-01, 7.92555238e-01, 8.55351910e-01,
#         7.73207376e-01, 6.79266129e-01],
#        [8.94132911e-01, 2.51755432e-01, 9.94499633e-01, 5.41549597e-01,
#         2.46617641e-01, 8.84359550e-02, 7.90002707e-01, 5.82936453e-01,
#         7.58093714e-02, 7.26150997e-01],
#        [1.07339927e-01, 4.51161716e-01, 8.27147990e-01, 8.60470314e-01,
#         1.46487415e-01, 7.37493164e-01, 7.80222788e-01, 6.40224826e-01,
#         3.98082115e-01, 3.70508255e-01],
#        [1.59466266e-01, 5.85513634e-01, 8.44472981e-01, 1.64501129e-01,
#         4.71725873e-01, 7.34469361e-01, 9.03295856e-01, 9.95751269e-01,
#         4.86660334e-01, 8.53339071e-01],
#        [8.92481170e-01, 5.99028277e-01, 8.30516100e-01, 9.77531478e-01,
#         9.93386492e-01, 2.77789916e-01, 8.12509348e-01, 6.82834529e-01,
#         6.20440033e-01, 1.12807900e-01],
#        [3.79578425e-01, 9.69558628e-01, 9.10843923e-01, 9.52497551e-01,
#         5.70231264e-01, 8.66662722e-02, 9.35679895e-01, 7.20240066e-01,
#         7.81789302e-01, 4.22568463e-01],
#        [6.55445556e-01, 2.80049470e-01, 4.05777128e-02, 9.74538665e-01,
#         9.38790020e-01, 4.79836328e-01, 6.55872396e-01, 3.24963657e-03,
#         7.68129365e-02, 9.24893410e-01],
#        [4.29818070e-01, 9.41971425e-01, 5.97167734e-01, 4.46602100e-01,
#         8.14325471e-01, 3.10473529e-01, 4.52297414e-01, 1.99412672e-01,
#         5.98627869e-02, 3.92975813e-01],
#        [4.34299528e-01, 8.85857642e-01, 3.84875857e-02, 8.18273010e-01,
#         7.23823170e-01, 9.36321767e-01, 6.33417410e-01, 6.06733006e-01,
#         4.95406542e-01, 4.97528288e-01],
#        [7.78112748e-01, 1.80720959e-01, 5.84605360e-01, 3.42890189e-01,
#         7.57977457e-01, 1.39270048e-01, 3.48631181e-01, 1.48063150e-01,
#         9.83445811e-01, 3.38246423e-01],
#        [4.88945219e-01, 4.99626501e-01, 7.43640758e-01, 9.42475683e-01,
#         3.15973811e-01, 8.15816144e-02, 9.87553691e-01, 3.45740011e-01,
#         4.75141422e-01, 9.95315872e-01],
#        [3.70826373e-02, 2.15108473e-01, 7.13005143e-01, 9.56209916e-01,
#         9.73236605e-01, 3.41889767e-01, 4.60365715e-01, 4.77131715e-02,
#         8.93403505e-01, 2.14777046e-01],
#        [5.70507216e-01, 1.20748247e-02, 1.37231623e-01, 5.14012827e-01,
#         9.45090948e-01, 9.52694368e-01, 1.91365363e-01, 8.94919718e-01,
#         3.10651852e-01, 1.71704746e-01],
#        [6.64460936e-01, 2.25665876e-01, 4.88874580e-01, 9.57157311e-01,
#         6.01917456e-01, 1.95260999e-01, 9.87787394e-01, 9.24617320e-01,
#         3.16984752e-01, 4.92991883e-01],
#        [2.81077914e-01, 5.32688695e-01, 7.20111927e-01, 4.54107771e-01,
#         2.81094401e-01, 3.87661326e-01, 1.23952089e-01, 8.84872294e-01,
#         5.89680575e-01, 1.12941726e-01],
#        [2.15041901e-03, 4.67459843e-01, 5.28637025e-01, 7.53737436e-01,
#         2.87867513e-01, 1.65403733e-01, 5.98662184e-01, 2.18397195e-01,
#         5.38679539e-01, 4.97811836e-02],
#        [4.79546553e-01, 4.95915243e-01, 2.95293773e-02, 1.95095630e-01,
#         1.20770062e-01, 3.29955084e-01, 9.50214945e-01, 9.09687464e-01,
#         6.97486344e-01, 4.77365992e-01],
#        [8.31434234e-02, 5.55829806e-01, 5.53436238e-01, 3.71184398e-01,
#         8.44777927e-01, 5.51250972e-01, 6.55970303e-02, 7.40848989e-01,
#         4.14746116e-01, 7.57076976e-02],
#        [5.96940008e-02, 6.63816463e-01, 8.23463595e-01, 8.64483308e-01,
#         1.43583387e-02, 5.24499868e-01, 3.62182368e-01, 4.21608945e-01,
#         2.73680678e-01, 6.66766758e-01],
#        [3.82068502e-01, 3.34287769e-01, 6.71443561e-01, 1.16290307e-01,
#         2.54942339e-01, 4.34953904e-01, 8.83327298e-01, 8.09518770e-01,
#         1.79615803e-02, 3.37202020e-01]])

# %% [markdown]
# ### Linear Model

# %%
def linear(m, theta):
    w = theta
    return m.dot(w)

# %% [markdown]
# ### Log softmax + NLLloss = Cross Entropy

# %%
def log_softmax(x):
    e_x = np.exp(x - np.max(x))
    return np.log(e_x / e_x.sum())

# %%
def NLLLoss(logs, targets):
    out = logs[range(len(targets)), targets]
    return -out.sum()/len(out)

# %%
def log_softmax_crossentropy_with_logits(logits,target):

    out = np.zeros_like(logits)
    out[np.arange(len(logits)),target] = 1
    
    softmax = np.exp(logits) / np.exp(logits).sum(axis=-1,keepdims=True)
    
    return (- out + softmax) / logits.shape[0]

# %% [markdown]
# ### Forward function

# %%
def forward(context_idxs, theta):
    m = embeddings[context_idxs].reshape(1, -1)
    n = linear(m, theta)
    o = log_softmax(n)
    return m, n, o

# %% [markdown]
# ### Backward function

# %%
def backward(preds, theta, target_idxs):
    m, n, o = preds
    dlog = log_softmax_crossentropy_with_logits(n, target_idxs)
    dw = m.T.dot(dlog)
    return dw

# %% [markdown]
# ### Optimize function

# %%
def optimize(theta, grad, lr=0.03):
    theta -= grad * lr
    return theta

# %% [markdown]
# ### Training function

# %%
theta = np.random.uniform(-1, 1, (2 * context_size * embed_dim, vocab_size))

# %%
# [(['we', 'are', 'to', 'study'], 'about'), (['are', 'about', 'study', 'the'], 'to'), (['about', 'to', 'the', 'idea'], 'study'), (['to', 'study', 'idea', 'of'], 'the'), (['study', 'the', 'of', 'computational'], 'idea')]



epoch_losses = {}

for epoch in range(80):

    losses =  []

    for context, target in data:
        context_idxs = np.array([word_to_ix[w] for w in context])
        preds = forward(context_idxs, theta)

        target_idxs = np.array([word_to_ix[target]])
        loss = NLLLoss(preds[-1], target_idxs)

        losses.append(loss)

        grad = backward(preds, theta, target_idxs)
        theta = optimize(theta, grad, lr=0.03)
        
     
    epoch_losses[epoch] = losses

# %% [markdown]
# ### Plot loss/epoch

# %%
ix = np.arange(0,80)

fig = plt.figure()
fig.suptitle('Epoch/Losses', fontsize=20)
plt.plot(ix,[epoch_losses[i][0] for i in ix])
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Losses', fontsize=12)
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# ### Predict function

# %%
def predict(words):
    context_idxs = np.array([word_to_ix[w] for w in words])
    preds = forward(context_idxs, theta)
    word = ix_to_word[np.argmax(preds[-1])]
    
    return word

# %%
# (['we', 'are', 'to', 'study'], 'about')
predict(['we', 'are', 'to', 'study'])
# Out:
# 'about'

# %% [markdown]
# ### Accuracy

# %%
def accuracy():
    wrong = 0

    for context, target in data:
        if(predict(context) != target):
            wrong += 1
            
    return (1 - (wrong / len(data)))

# %%
accuracy()
# Out:
# 1.0
